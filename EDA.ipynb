# %%
import numpy as np
import pandas as pd
df = pd.read_csv("2.EDA\Fortune_Bay.csv", skiprows=[1])
df.head()
# Out:
#       station_name                  time  longitude   latitude  wind_spd_avg  \
# 0  smb_fortune_bay  2019-06-26T17:23:41Z -53.135668  47.388615           0.7
# 1  smb_fortune_bay  2019-06-26T17:53:41Z -53.135645  47.388567           1.1
# 2  smb_fortune_bay  2019-06-26T18:23:41Z -53.135603  47.388607           1.1
# 3  smb_fortune_bay  2019-06-26T18:53:41Z -53.135645  47.388697           1.2
# 4  smb_fortune_bay  2019-06-26T19:23:41Z -53.135637  47.388680           0.8
#
#    wind_spd_max  wind_dir_avg  air_temp_avg  air_pressure_avg  \
# 0           1.8          21.0          45.2            1025.3
# 1           3.4          36.0          43.8            1025.3
# 2           2.4          31.0          43.0            1025.5
# 3           2.7          38.0          47.8            1025.7
# 4           2.0          29.0          45.8            1025.7
#
#    air_humidity_avg  air_dewpoint_avg  surface_temp_avg  wave_ht_max  \
# ...

# %%
list_of_column_names = list(df.columns)
# displaying the list of column names
print('List of column names: ', list_of_column_names)
# Out:
# List of column names:  ['station_name', 'time', 'longitude', 'latitude', 'wind_spd_avg', 'wind_spd_max', 'wind_dir_avg', 'air_temp_avg', 'air_pressure_avg', 'air_humidity_avg', 'air_dewpoint_avg', 'surface_temp_avg', 'wave_ht_max', 'wave_ht_sig', 'wave_period_max', 'wave_dir_avg', 'wave_spread_avg', 'curr_spd_avg', 'curr_dir_avg']

# %%
# the shape of dataframe
df.shape
# Out:
# (13858, 19)

# %%
# it will provide you the information about all the columns that may include count of non-null and datatype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13858 entries, 0 to 13857
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station_name      13858 non-null  object
#  1   time              13858 non-null  object
#  2   longitude         11717 non-null  float64
#  3   latitude          11717 non-null  float64
#  4   wind_spd_avg      13732 non-null  float64
#  5   wind_spd_max      13732 non-null  float64
#  6   wind_dir_avg      13732 non-null  float64
#  7   air_temp_avg      9340 non-null   float64
#  8   air_pressure_avg  13751 non-null  float64
#  9   air_humidity_avg  6464 non-null   float64
#  10  air_dewpoint_avg  6450 non-null   float64
#  11  surface_temp_avg  12332 non-null  float64
#  12  wave_ht_max       13747 non-null  float64
#  13  wave_ht_sig       13747 non-null  float64
#  14  wave_period_max   13747 non-null  float64
#  15  wave_dir_avg      13747 non-null  float64
# ...

# %%
# you can convert the datatype of the columns if you are required to do so
# in this example, I converted column 'time' from object to date_time
print(df['time'].dtypes)
df['time'] = pd.to_datetime(df['time'])
print(df['time'].dtypes)
# Out:
# object
# datetime64[ns, UTC]

# %%
# changing the column name
df = df.rename(columns={'time': 'DATE & TIME'})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13858 entries, 0 to 13857
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station_name      13858 non-null  object
#  1   DATE & TIME       13858 non-null  datetime64[ns, UTC]
#  2   longitude         11717 non-null  float64
#  3   latitude          11717 non-null  float64
#  4   wind_spd_avg      13732 non-null  float64
#  5   wind_spd_max      13732 non-null  float64
#  6   wind_dir_avg      13732 non-null  float64
#  7   air_temp_avg      9340 non-null   float64
#  8   air_pressure_avg  13751 non-null  float64
#  9   air_humidity_avg  6464 non-null   float64
#  10  air_dewpoint_avg  6450 non-null   float64
#  11  surface_temp_avg  12332 non-null  float64
#  12  wave_ht_max       13747 non-null  float64
#  13  wave_ht_sig       13747 non-null  float64
#  14  wave_period_max   13747 non-null  float64
# ...

# %%
# Feature extraction
# I have extracted DATE from DATE & TIME
df['DATE'] = df['DATE & TIME'].dt.date
df.head()
print(df['DATE'].dtypes)
# Out:
# object

# %%
# convert new column to other data type if you want
# I again converted the data type of DATE form object to datetime type
df['DATE'] = pd.to_datetime(df['DATE'])
print(df['DATE'].dtypes)
# Out:
# datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13858 entries, 0 to 13857
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station_name      13858 non-null  object
#  1   DATE & TIME       13858 non-null  datetime64[ns, UTC]
#  2   longitude         11717 non-null  float64
#  3   latitude          11717 non-null  float64
#  4   wind_spd_avg      13732 non-null  float64
#  5   wind_spd_max      13732 non-null  float64
#  6   wind_dir_avg      13732 non-null  float64
#  7   air_temp_avg      9340 non-null   float64
#  8   air_pressure_avg  13751 non-null  float64
#  9   air_humidity_avg  6464 non-null   float64
#  10  air_dewpoint_avg  6450 non-null   float64
#  11  surface_temp_avg  12332 non-null  float64
#  12  wave_ht_max       13747 non-null  float64
#  13  wave_ht_sig       13747 non-null  float64
#  14  wave_period_max   13747 non-null  float64
# ...

# %%
# Rearrange the columns
# Here, I put DATE column next to the DATE & TIME to avoid confusion
cols = df.columns.tolist()
cols = cols[0:2] + cols[-1:] + cols[2:-1]
len(cols)
df = df[cols]
df.head()
# Out:
#       station_name               DATE & TIME       DATE  longitude   latitude  \
# 0  smb_fortune_bay 2019-06-26 17:23:41+00:00 2019-06-26 -53.135668  47.388615
# 1  smb_fortune_bay 2019-06-26 17:53:41+00:00 2019-06-26 -53.135645  47.388567
# 2  smb_fortune_bay 2019-06-26 18:23:41+00:00 2019-06-26 -53.135603  47.388607
# 3  smb_fortune_bay 2019-06-26 18:53:41+00:00 2019-06-26 -53.135645  47.388697
# 4  smb_fortune_bay 2019-06-26 19:23:41+00:00 2019-06-26 -53.135637  47.388680
#
#    wind_spd_avg  wind_spd_max  wind_dir_avg  air_temp_avg  air_pressure_avg  \
# 0           0.7           1.8          21.0          45.2            1025.3
# 1           1.1           3.4          36.0          43.8            1025.3
# 2           1.1           2.4          31.0          43.0            1025.5
# 3           1.2           2.7          38.0          47.8            1025.7
# 4           0.8           2.0          29.0          45.8            1025.7
#
# ...

# %%
# Use describe() command to see the description of the dataframe that include mean, max, min, std, percentiles
# it will also give you the idea of the deviation of the data. Here we see the different count values
df.describe()
# Out:
#           longitude      latitude  wind_spd_avg  wind_spd_max  wind_dir_avg  \
# count  11717.000000  11717.000000  13732.000000  13732.000000  13732.000000
# mean     -55.392300     47.264456      7.561360      9.401092    207.881590
# std        0.495062      0.039090      4.093555      5.064215    100.549255
# min      -56.029590     46.568962      0.100000      0.400000      0.000000
# 25%      -55.502247     47.258855      4.600000      5.600000    128.000000
# 50%      -55.499422     47.259953      7.200000      8.800000    242.000000
# 75%      -55.497982     47.261060     10.100000     12.400000    288.000000
# max      -52.607535     47.821110     22.000000     38.100000    360.000000
#
#        air_temp_avg  air_pressure_avg  air_humidity_avg  air_dewpoint_avg  \
# count   9340.000000      13751.000000       6464.000000       6450.000000
# mean      12.590407       1012.717286         94.951717          1.601953
# ...

# %%
# Check if there are NULL values
df.isnull().sum()
# Out:
# station_name           0
# DATE & TIME            0
# DATE                   0
# longitude           2141
# latitude            2141
# wind_spd_avg         126
# wind_spd_max         126
# wind_dir_avg         126
# air_temp_avg        4518
# air_pressure_avg     107
# air_humidity_avg    7394
# air_dewpoint_avg    7408
# surface_temp_avg    1526
# wave_ht_max          111
# wave_ht_sig          111
# wave_period_max      111
# wave_dir_avg         111
# wave_spread_avg      111
# curr_spd_avg        1532
# curr_dir_avg        1532
# dtype: int64

# %%
# Fill the null values with suitable way
# Here, I used MODE to fill longitude and latitude
df['latitude'].fillna(df['latitude'].mode, inplace=True)
df['longitude'].fillna(df['longitude'].mode, inplace=True)

# %%
df.isnull().sum()
# Out:
# station_name           0
# DATE & TIME            0
# DATE                   0
# longitude              0
# latitude               0
# wind_spd_avg         126
# wind_spd_max         126
# wind_dir_avg         126
# air_temp_avg        4518
# air_pressure_avg     107
# air_humidity_avg    7394
# air_dewpoint_avg    7408
# surface_temp_avg    1526
# wave_ht_max          111
# wave_ht_sig          111
# wave_period_max      111
# wave_dir_avg         111
# wave_spread_avg      111
# curr_spd_avg        1532
# curr_dir_avg        1532
# dtype: int64

# %%
# This data belongs to weather. Assuming, not much variation in the weather in small interval of time, I used previous values to fill the NULL values
cols = ['wind_spd_avg','wind_spd_max','wind_dir_avg', 'air_temp_avg', 'wind_dir_avg', 'air_temp_avg', 'air_pressure_avg', 'air_humidity_avg', 'air_dewpoint_avg', 'surface_temp_avg', 'wave_ht_max', 'wave_ht_sig', 'wave_period_max', 'wave_dir_avg', 'wave_spread_avg', 'curr_spd_avg', 'curr_dir_avg']
df[cols] = df[cols].fillna(method='ffill', axis=0)

# %%
df.isnull().sum()
# Out:
# station_name         0
# DATE & TIME          0
# DATE                 0
# longitude            0
# latitude             0
# wind_spd_avg         0
# wind_spd_max         0
# wind_dir_avg         0
# air_temp_avg         0
# air_pressure_avg     0
# air_humidity_avg    10
# air_dewpoint_avg    10
# surface_temp_avg     2
# wave_ht_max          0
# wave_ht_sig          0
# wave_period_max      0
# wave_dir_avg         0
# wave_spread_avg      0
# curr_spd_avg         2
# curr_dir_avg         2
# dtype: int64

# %%
# drop NULL values
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# station_name        0
# DATE & TIME         0
# DATE                0
# longitude           0
# latitude            0
# wind_spd_avg        0
# wind_spd_max        0
# wind_dir_avg        0
# air_temp_avg        0
# air_pressure_avg    0
# air_humidity_avg    0
# air_dewpoint_avg    0
# surface_temp_avg    0
# wave_ht_max         0
# wave_ht_sig         0
# wave_period_max     0
# wave_dir_avg        0
# wave_spread_avg     0
# curr_spd_avg        0
# curr_dir_avg        0
# dtype: int64

# %%
df.head()
# Out:
#        station_name               DATE & TIME       DATE longitude latitude  \
# 10  smb_fortune_bay 2019-06-26 22:23:41+00:00 2019-06-26  -53.1357  47.3886
# 11  smb_fortune_bay 2019-06-26 22:53:41+00:00 2019-06-26  -53.1356  47.3887
# 12  smb_fortune_bay 2019-06-26 23:23:41+00:00 2019-06-26  -53.1356  47.3886
# 13  smb_fortune_bay 2019-06-26 23:53:41+00:00 2019-06-26  -53.1357  47.3886
# 14  smb_fortune_bay 2019-06-27 00:23:41+00:00 2019-06-27  -53.1356  47.3886
#
#     wind_spd_avg  wind_spd_max  wind_dir_avg  air_temp_avg  air_pressure_avg  \
# 10           0.4           1.2          23.0          33.1            1026.9
# 11           0.5           1.0          56.0          32.2            1026.8
# 12           0.3           1.0          32.0          31.2            1027.0
# 13           0.3           0.8          76.0          30.0            1027.2
# 14           0.4           1.0         182.0          28.4            1027.7
#
# ...

# %%
# You can reset the index if require
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#       station_name               DATE & TIME       DATE longitude latitude  \
# 0  smb_fortune_bay 2019-06-26 22:23:41+00:00 2019-06-26  -53.1357  47.3886
# 1  smb_fortune_bay 2019-06-26 22:53:41+00:00 2019-06-26  -53.1356  47.3887
# 2  smb_fortune_bay 2019-06-26 23:23:41+00:00 2019-06-26  -53.1356  47.3886
# 3  smb_fortune_bay 2019-06-26 23:53:41+00:00 2019-06-26  -53.1357  47.3886
# 4  smb_fortune_bay 2019-06-27 00:23:41+00:00 2019-06-27  -53.1356  47.3886
#
#    wind_spd_avg  wind_spd_max  wind_dir_avg  air_temp_avg  air_pressure_avg  \
# 0           0.4           1.2          23.0          33.1            1026.9
# 1           0.5           1.0          56.0          32.2            1026.8
# 2           0.3           1.0          32.0          31.2            1027.0
# 3           0.3           0.8          76.0          30.0            1027.2
# 4           0.4           1.0         182.0          28.4            1027.7
#
# ...

# %%
# Use describe() command to see the description of the dataframe
# Now, all the columns has same value for counts. Means no NULL values
df.describe()
# Out:
#        wind_spd_avg  wind_spd_max  wind_dir_avg  air_temp_avg  \
# count  13848.000000  13848.000000  13848.000000  13848.000000
# mean       7.544570      9.380026    207.923816     19.623816
# std        4.091651      5.063263    100.454573     16.958788
# min        0.100000      0.400000      0.000000    -11.300000
# 25%        4.500000      5.600000    128.000000      2.000000
# 50%        7.200000      8.800000    242.000000     34.300000
# 75%       10.100000     12.400000    288.000000     34.300000
# max       22.000000     38.100000    360.000000     64.700000
#
#        air_pressure_avg  air_humidity_avg  air_dewpoint_avg  surface_temp_avg  \
# count      13848.000000      13848.000000      13848.000000      13848.000000
# mean        1012.720126        102.828502         27.562312          8.112226
# std           11.136824         10.157239         24.975362          5.412620
# min          967.000000         43.300000        -15.600000         -0.200000
# ...

# %%
# Check the distribution by plotting histogram
df.hist(figsize=(15,15))
# Out:
# array([[<AxesSubplot:title={'center':'wind_spd_avg'}>,
#         <AxesSubplot:title={'center':'wind_spd_max'}>,
#         <AxesSubplot:title={'center':'wind_dir_avg'}>,
#         <AxesSubplot:title={'center':'air_temp_avg'}>],
#        [<AxesSubplot:title={'center':'air_pressure_avg'}>,
#         <AxesSubplot:title={'center':'air_humidity_avg'}>,
#         <AxesSubplot:title={'center':'air_dewpoint_avg'}>,
#         <AxesSubplot:title={'center':'surface_temp_avg'}>],
#        [<AxesSubplot:title={'center':'wave_ht_max'}>,
#         <AxesSubplot:title={'center':'wave_ht_sig'}>,
#         <AxesSubplot:title={'center':'wave_period_max'}>,
#         <AxesSubplot:title={'center':'wave_dir_avg'}>],
#        [<AxesSubplot:title={'center':'wave_spread_avg'}>,
#         <AxesSubplot:title={'center':'curr_spd_avg'}>,
#         <AxesSubplot:title={'center':'curr_dir_avg'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
# Trim dataset
# In above histogram, we can see some outliers in the case of wave_period_max, wave_spread_avg, curr_spd_avg, dewpoint_avg, air_temp_avg
# Number of counts of extreme values in wave_period_max, wave_spread_avg, curr_spd_avg is less. So I removed it
df = df[df['wave_period_max'] < 20]
df = df[df['wave_spread_avg'] < 60]
df = df[df['curr_spd_avg'] < 2000]

# But in air_dewpoint_avg, air_temp_avg cases, count is more. Dropping these values will impact the performance. So I did not drop it.

# %%
df.hist(figsize=(15,15))
# See the description again. There is not much change in the count as compare to the previous count.
df.describe()
# Out:
#        wind_spd_avg  wind_spd_max  wind_dir_avg  air_temp_avg  \
# count  13293.000000  13293.000000  13293.000000  13293.000000
# mean       7.811720      9.672309    211.083879     18.623351
# std        3.946832      4.943650     99.820410     16.360458
# min        0.300000      0.500000      0.000000    -11.300000
# 25%        4.900000      6.000000    133.000000      1.800000
# 50%        7.400000      9.000000    247.000000     34.300000
# 75%       10.300000     12.600000    289.000000     34.300000
# max       22.000000     38.100000    360.000000     39.900000
#
#        air_pressure_avg  air_humidity_avg  air_dewpoint_avg  surface_temp_avg  \
# count      13293.000000      13293.000000      13293.000000      13293.000000
# mean        1012.782103        102.534793         26.266095          7.787294
# std           11.269064         10.261313         24.577037          5.241976
# min          967.000000         43.300000        -15.600000         -0.200000
# ...

# %%
# Here we plot box plot to see the outliers and distribution plot again.
# Distribution plot is similar to histogram. If the things are clear to you, you can ignore distribution plots.
import seaborn as sns
import matplotlib.pyplot as plt
def plotchart(col):
    fix,(ax1,ax2)=plt.subplots(1,2,figsize=(7,5))
    sns.boxplot(col,orient='v',ax=ax1)
    ax1.set_ylabel=col.name
    ax1.set_title('Box Plot Of {}'.format(col.name))
    sns.distplot(col,ax=ax2)
    ax2.set_title('Distribution Plot Of {}'.format(col.name))

# %%
##cols=['wind_spd_avg','wind_spd_max','wind_dir_avg', 'air_temp_avg', 'wind_dir_avg', 'air_temp_avg', 'air_pressure_avg', 'air_humidity_avg', 'air_dewpoint_avg', 'surface_temp_avg', 'wave_ht_max', 'wave_ht_sig', 'wave_period_max', 'wave_dir_avg', 'wave_spread_avg', 'curr_spd_avg', 'curr_dir_avg']
for i in cols:
    plotchart(df[i])
# Out:
# c:\users\daniel\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\users\daniel\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\_core.py:1319: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# c:\users\daniel\appdata\local\programs\python\python38-32\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
# Function for finding th outliers. You can return outliers using following code
def findOutliers(column):
    outliers = []
    Q1 = column.quantile(.25)
    Q3 = column.quantile(.75)
    IQR = Q3-Q1
    lower_limit=Q1-(1.5*IQR)
    upper_limit=Q1+(1.5*IQR)
    for out in column:
        if out > upper_limit or out < lower_limit:
            outliers.append(out)
    return lower_limit, upper_limit, np.array(outliers)

# %%
# Code for removing outliers. I don't need this. If you want to remove the outliers, you can try following code
#for i in cols:
#    a=[]
#    print(i)
#    #print(df[i])
#    #print(findOutliers(df[i]))
#    a=findOutliers(df[i])[2]
#    a.tolist()
#    l=len(a)
#    print(l)
#    if (l>0):
#       for l1 in range(l):
#           print(df[i])
#           print('****',a[l1])
#           #df[i].drop(a[l1])
#           df.drop(df.index[df[i] == a[l1]],inplace=True)
#   #print(len(findOutliers(df[i])[2]))

# %%
# Feature selection
# This step is to see the co-relation between the columns
# Here, I used HeatMap to see the co-relation
# Below diagram will give you the idea about the co-relation between columns

corrmat = df.corr()
f, ax = plt.subplots(figsize=(12,12))
sns.heatmap(corrmat, ax = ax, cmap = "YlGnBu", linewidths = 0.1, annot = True)
# Out:
# <AxesSubplot:>

# %%
corrmat['wave_ht_max']
# Out:
# wind_spd_avg        0.813596
# wind_spd_max        0.819601
# wind_dir_avg        0.225320
# air_temp_avg       -0.146671
# air_pressure_avg   -0.339793
# air_humidity_avg   -0.082391
# air_dewpoint_avg   -0.136911
# surface_temp_avg   -0.322932
# wave_ht_max         1.000000
# wave_ht_sig         0.988904
# wave_period_max     0.366614
# wave_dir_avg        0.085601
# wave_spread_avg    -0.368295
# curr_spd_avg        0.330140
# curr_dir_avg       -0.140579
# Name: wave_ht_max, dtype: float64

# %%
cor_target = abs(corrmat['wave_ht_max'])
# Selecting highly correlated features
# I have selected features where co-relation is greater than equal to 0.5

relevant_features = cor_target[(cor_target >= 0.4)]
print(relevant_features)
# Out:
# wind_spd_avg    0.813596
# wind_spd_max    0.819601
# wave_ht_max     1.000000
# wave_ht_sig     0.988904
# Name: wave_ht_max, dtype: float64

# %%
cols = ['wind_spd_avg' ,'wind_spd_max', 'wave_ht_max', 'wave_ht_sig']

df2 = pd.DataFrame()
for col in cols:
    df2[col] = df [col]
sns.pairplot(df2)

# %%
# You can also handle the skewed dataset using log transformation.
# e.g I did it for 'wave_ht_max'. You can try this and see the impact of this change.

df['wave_ht_max'] = np.log(df['wave_ht_max'])
df['wave_ht_max'].skew()
# Out:
# -0.399403106846025

# %%
# Seeing the impact of log transform and skewness reduce in 'wave_ht_max'
cols = ['wind_spd_avg' ,'wind_spd_max', 'wave_ht_max', 'wave_ht_sig']

df2 = pd.DataFrame()
for col in cols:
    df2[col] = df [col]
sns.pairplot(df2)
